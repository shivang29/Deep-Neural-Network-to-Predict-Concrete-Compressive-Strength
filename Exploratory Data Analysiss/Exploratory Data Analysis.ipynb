# %% [markdown]
# **Predicting Concrete Compressive Strength - Exploratory Data Analysis**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()

# %% [markdown]
# **Import DataSet**

# %%
url = 'https://raw.githubusercontent.com/shivang29/Deep-Neural-Network-to-Predict-Concrete-Compressive-Strength/main/Exploratory%20Data%20Analysiss/Concrete_Data_Original.csv'
df1 = pd.read_csv(url)
url = 'https://raw.githubusercontent.com/shivang29/Deep-Neural-Network-to-Predict-Concrete-Compressive-Strength/main/Exploratory%20Data%20Analysiss/Concrete_Data_Transformed_v1.csv'
df2 = pd.read_csv(url)
original_data = df1.copy()
ratio_data = df2.copy()

# %% [markdown]
# **Exploring the Original Data**

# %%
original_data.head()
# Out:
#    Cement (component 1)(kg in a m^3 mixture)  ...  Concrete compressive strength(MPa, megapascals)
# 0                                      540.0  ...                                             79.99
# 1                                      540.0  ...                                             61.89
# 2                                      332.5  ...                                             40.27
# 3                                      332.5  ...                                             41.05
# 4                                      198.6  ...                                             44.30
#
# [5 rows x 9 columns]

# %%
original_data.describe()
# Out:
#        Cement (component 1)(kg in a m^3 mixture)  ...  Concrete compressive strength(MPa, megapascals)
# count                                1030.000000  ...                                       1030.000000
# mean                                  281.167864  ...                                         35.817961
# std                                   104.506364  ...                                         16.705742
# min                                   102.000000  ...                                          2.330000
# 25%                                   192.375000  ...                                         23.710000
# 50%                                   272.900000  ...                                         34.445000
# 75%                                   350.000000  ...                                         46.135000
# max                                   540.000000  ...                                         82.600000
#
# [8 rows x 9 columns]

# %% [markdown]
# Let us examine the original data file by plotting pair plots. This will show us any potential relationships between the different dataset features

# %%
sns.pairplot(original_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:64: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self.fig.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:64: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self.fig.tight_layout(*args, **kwargs)

# %% [markdown]
# **Exploring the Transformed Data**

# %%
ratio_data.head()
# Out:
#    Cementitious_Ratio  Slag_Ratio  ...  Age  Compressive_Strength
# 0            0.205086    0.000000  ...    1             12.638095
# 1            0.167391    0.000000  ...    1              6.267337
# 2            0.058291    0.087436  ...    3              8.063422
# 3            0.145726    0.000000  ...    3             15.049193
# 4            0.085350    0.056900  ...    3              9.131420
#
# [5 rows x 9 columns]

# %%
ratio_data.describe()
# Out:
#        Cementitious_Ratio   Slag_Ratio  ...          Age  Compressive_Strength
# count         1030.000000  1030.000000  ...  1030.000000           1030.000000
# mean             0.142726     0.031643  ...    45.662136             35.817836
# std              0.040513     0.036961  ...    63.169912             16.705679
# min              0.044815     0.000000  ...     1.000000              2.331808
# 25%              0.124002     0.000000  ...     7.000000             23.707115
# 50%              0.143272     0.009455  ...    28.000000             34.442774
# 75%              0.162794     0.061972  ...    56.000000             46.136287
# max              0.259517     0.150339  ...   365.000000             82.599225
#
# [8 rows x 9 columns]

# %%
sns.pairplot(ratio_data)

# %% [markdown]
# **Conclusion**

# %% [markdown]
# We will use the original data during modeling in order to avoid the multicollinearity of the transformed data. Cement, fly ash, and water should be kept as separate quantities during modeling
# All input values should be scaled and run through an artificial neural network (ANN) in a train-test split.
# The performance of the ANN model should be compared with the performance of linear models trained on cement vs. compressive strength, fly ash ratio vs. compressive strength, etc. to determine the best model.
